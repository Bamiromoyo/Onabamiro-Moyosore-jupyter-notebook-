# %% [markdown]
# ## NAME: ONABAMIRO MOYOSORE FAITH

# %% [markdown]
# ## MATRIC NUMBER: 23/0550

# %% [markdown]
# ## DEPARTMENT: INFORMATION TECHNOLOGY

# %% [markdown]
# ## GROUP: C

# %% [markdown]
# ## 1. DATA TYPES AND EXAMPLES

# %%
# Integer Example
age = 25
print ("Integer:", age)
# Out:
# Integer: 25

# %%
# Float Example
height = 5.9
print( "Float:", height)
# Out:
# Float: 5.9

# %%
# Complex Example
z = 3+4j
print("Complex:", z)
# Out:
# Complex: (3+4j)

# %%
# String Example
name = "Moyosore"
print("String:", name)
# Out:
# String: Moyosore

# %%
# Booldan Example
is_student = True
print("Boolean:", is_student)
# Out:
# Boolean: True

# %% [markdown]
# ##  2. DATA STRUCTURES AND EXAMPLES

# %%
# List Example
fruits = ["apple", "banana" , "cherry" ,]
print("List:", fruits)
# Out:
# List: ['apple', 'banana', 'cherry']

# %%
# Tuple Example
colors = ("red", "green" , "blue")
print("Tuple:", colors)
# Out:
# Tuple: ('red', 'green', 'blue')

# %%
# Set Example
numbers = {1,2,3,4,5}
print("Set:", numbers)
# Out:
# Set: {1, 2, 3, 4, 5}

# %%
# Dictionary Example
person = {"name": "Moyosore", "age": 25}
print("Dictionary:", person)
# Out:
# Dictionary: {'name': 'Moyosore', 'age': 25}
